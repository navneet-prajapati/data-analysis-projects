# %% [markdown]
# ## 1.. How to read csv data or how to load data  !

# %%
### lets import all the necessary packages !

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comments = pd.read_csv(r"R:\All_Datasets\1.. Youtube\Datasets/UScomments.csv" , on_bad_lines= "skip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 comments = pd.read_csv(r"R:\All_Datasets\1.. Youtube\Datasets/UScomments.csv" , on_bad_lines= "skip")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
### above is a warning , u can ignore that ..

# %%
comments.head(5)

# %%
type(comments) ## ie above "data" belongs to dataframe data-structure

# %%
## lets find out missing values in your data
comments.isnull().sum()

# %%
## drop missing values as we have very few & lets update dataframe as well..
comments.dropna(inplace= True)

# %%
comments.isnull().sum()

# %% [markdown]
# ## 2.. Perform Sentiment Analysis
#
#     In short , Sentiment analysis is all about analysing sentiments of Users..
#     ( ie whether whether they feel positive, negative, or neutral)..
#     ie Understand Viewer Emotions !

# %%
'''

Sentiment analysis is all about finding sentiment scores(polarity) which range between (-1,+1)
more it is close to -1 , ie more it is negative ( This is the worst movie ever)
more close to 0 means ,, it is neutral sentence ( This movie is Okay)
more it is +1 , more it is +ve ( This case study is amazing )

Ways to perform Analysis :

Methods:

TextBlob – simple, beginner-friendly.
VADER (NLTK) – fast, good for tweets/reviews.
Transformers (BERT, RoBERTa, DistilBERT) – high accuracy, context-aware.
Social Media Models – trained on tweets, handle slang/emojis well.


Best choice:

Quick projects → VADER
Complex/modern text → Transformers
Enterprise use → Cloud NLP APIs

'''

# %%
# !pip install nltk

# %%
import nltk

# %%
# nltk.download("vader_lexicon")

# %%
# Initialize VADER

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
comments["comment_text"]

# %%
sia.polarity_scores("MY FAN . attendance")['compound'] # compound score = overall sentiment

# %%
'''

If comment_text has non-string values (NaN, None, numbers, etc.), polarity_scores() will throw errors.
✅ Fix → Convert each comment to string before analysis:

'''

# %%
sentimen_scores = []

for comment in comments["comment_text"]:
    score  = sia.polarity_scores(str(comment))['compound']
    sentimen_scores.append(score)

# %%
## for those of you who dont have good specifications , considering sample of data is a good option !

sample_df = comments[0:10000]

# %%
sentimen_scores

# %%
comments["polarity"] = sentimen_scores

### Inserting sentiment_values into comments dataframe while defining feature name as "polarity"

# %%
comments.head(5)

# %% [markdown]
# ## 3..  Wordcloud Analysis of your data

# %%
### Lets perform EDA for the highly Positve sentences ie Polarity value or sentiment value will be between 0.8 to 1 ..

# %%
filter_pos = (comments["polarity"] >= 0.8) & ((comments["polarity"] <= 1.0))

# %%
comments_positive = comments[filter_pos]

# %%
comments_positive.shape

# %%
### Lets perform EDA for the highly Positve sentences ie Polarity value or sentiment value will be between -1 to -0.8 ..

# %%
filter_neg = (comments["polarity"] >= -1.0) & ((comments["polarity"] <= -0.8))

# %%
comments_negative = comments[filter_neg]

# %%
comments_negative.shape

# %%
# ! pip install wordcloud

# %%
comments_positive["comment_text"]

# %%
type(comments_positive["comment_text"])

# %%
total_positive_comments = ' '.join(comments_positive["comment_text"])

# %%
total_positive_comments[0:1000]

# %%
from wordcloud import WordCloud , STOPWORDS

# %%
set(STOPWORDS)

# %%
wordcloud_positive = WordCloud(stopwords= set(STOPWORDS)).generate(total_positive_comments)

# %%
plt.imshow(wordcloud_positive)
plt.axis("off")

# %%
'''
Summary : 

Viewer comments reflect praise and excitement (love, amazing, awesome),
engagement and demand (please, keep, hope),
emotional connection (thank, God, wow),
and strong appreciation for content quality (video, music, visuals).

'''

# %%
total_negative_comments = ' '.join(comments_negative["comment_text"])

# %%
wordcloud_negative = WordCloud(stopwords= set(STOPWORDS)).generate(total_negative_comments)

# %%
plt.imshow(wordcloud_negative)
plt.axis("off")

# %%
'''

Comments show anger and hostility (e.g., fuck, hate, stupid),
reflect political/racial tensions (e.g., Trump, racist, black),
and contain aggressive/offensive language (bitch, hell), signaling strong dissatisfaction.

'''

# %% [markdown]
# ## 4.. Perform Emoji's Analysis

# %%
! pip install emoji==2.14.1
# is a most stable version till date , hence installing this version makes sense !

# %%
import emoji

# %%
emoji.__version__

# %%
comments.head(6)

# %%
### lets extract emoji from below comment

# %%
emojis_info = emoji.emoji_list("trending 😉")
emojis_info

# %%
## emoji.emoji_list() returns a list of dictionaries :

'''
Each item is a dictionary with three pieces of information:

match_start → index where the emoji begins.
match_end → index where the emoji ends 
emoji → The actual emoji found.

'''

# %%
## iterate on top of "list" & then use "list comprehension" to access each of the emoji..

[item["emoji"] for item in emojis_info]

# %%
comments["comment_text"]

# %%
## lets try to write above code in a more simpler & readable way for whole data :

# %%
all_emojis_found = []

for comment in comments["comment_text"]:
    emojis_info = emoji.emoji_list(comment)
    emojis_found = [item["emoji"] for item in emojis_info]
    all_emojis_found.extend(emojis_found)

# %%
all_emojis_found[0:10]

# %%
len(all_emojis_found)

# %%
### NOw we have to compute frequencies of each & every emoji in "all_emojis_list"..

# %%
from collections import Counter

# %%
emojis_count_list_top10 = Counter(all_emojis_found).most_common(10)

# %%
emojis_count_list_top10

# %%
emojis = [emoji for emoji , count in emojis_count_list_top10]

counts = [count for emoji , count in emojis_count_list_top10]

# %%
emojis

# %%
counts

# %%
# !pip install plotly

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
iplot([go.Bar(x = emojis , y = counts)])

# %%
## Conclusions : Majority of the customers are happy as most of them are using emojis like: funny , love , heart , outstanding..

# %% [markdown]
# ## 5.. Collect Entire data of Youtube !

# %%
import os

# %%
files= os.listdir(r'R:\All_Datasets\1.. Youtube\Datasets\additional_data')

# %%
files

# %%
## extracting csv files only from above list ..

files_csv = [file for file in files if '.csv' in file]

# %%
files_csv

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# #### different types of encoding-->>
#     Note : encoding may change depending upon data  , country data , sometimes regional data as well.
#     Fore more inforation on Encoding -- Follow below
# ### https://docs.python.org/3/library/codecs.html#standard-encodings¶

# %%
full_df = pd.DataFrame()
path = r'R:\All_Datasets\1.. Youtube\Datasets\additional_data'


for file in files_csv:
    current_df = pd.read_csv(path+'/'+file , encoding='iso-8859-1' , on_bad_lines= "skip")
    
    full_df = pd.concat([full_df , current_df] , ignore_index=True)

# %%
full_df.shape

# %% [markdown]
# ## 6.. How to export your data into (csv, json, db)

# %%
### lets export this data into various formats for further analysis :

# %%
'''

export your data into :
    a) csv 
    b) json
    c) db


'''

# %%
full_df.shape

# %%
full_df.duplicated()

# %%
full_df[full_df.duplicated()]

# %%
full_df[full_df.duplicated()].shape

# %%
full_df = full_df.drop_duplicates() ## lets drop duplicate rows ..

# %%
full_df.shape

# %% [markdown]
# #### a... Storing data into csv ..

# %%
full_df.to_csv(r"R:\All_Datasets\1.. Youtube\exporting_data/Youtube_whole_data.csv" , index = False)

# %% [markdown]
# #### b... Storing data into json

# %%
full_df.to_json(r"R:\All_Datasets\1.. Youtube\exporting_data/youtube_data.json" , orient="records")

# %% [markdown]
# #### c... Storing data into database

# %%
import sqlite3

# %%
conn = sqlite3.connect(r"R:\All_Datasets\1.. Youtube\exporting_data/youtube.db")

# %%
full_df.to_sql("Users" , conn , if_exists="replace" , index=False)

# %%
## As soon as u have u have your data into "youtube.db" , which has table has 'Users', now u can read data from this db file 'youtube.db' using sqlite3 & pandas

# %% [markdown]
# ## 7.. Which Category has the maximum likes ?

# %%
full_df.head(5)

# %%
full_df['category_id'].unique()

# %%
## lets read json file ..
json_df = pd.read_json(r'Z:\1.. Youtube\Datasets\additional_data/US_category_id.json')

# %%
json_df

# %%
json_df['items'][0]

### each row of 'Items' feature is dictionary ..

# %%
json_df['items'][1]

# %%
cat_dict = {}

for item in json_df['items'].values:
    ## cat_dict[key] = value (Syntax to insert key:value in dictionary)
    cat_dict[int(item['id'])] = item['snippet']['title']

# %%
cat_dict

# %%
full_df['category_name'] = full_df['category_id'].map(cat_dict)

# %%
full_df.head(4)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='category_name' , y='likes' , data=full_df)
plt.xticks(rotation='vertical')

# %% [markdown]
# ## 8.. Find out whether audience is engaged or not

# %%
full_df['like_rate'] = (full_df['likes']/full_df['views'])*100
full_df['dislike_rate'] = (full_df['dislikes']/full_df['views'])*100
full_df['comment_count_rate'] = (full_df['comment_count']/full_df['views'])*100

# %%
full_df.columns

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='category_name' , y='like_rate' , data=full_df)
plt.xticks(rotation='vertical')
plt.show()

# %%
### analysing relationship between views & likes

# %%
sns.regplot(x='views' , y='likes' , data = full_df)

# %%
full_df.columns

# %%
full_df[['views', 'likes', 'dislikes']].corr() ### finding co-relation values between ['views', 'likes', 'dislikes']

# %%
sns.heatmap(full_df[['views', 'likes', 'dislikes']].corr() , annot=True)

# %% [markdown]
# ## 9.. Which channels have the largest number of trending videos?

# %%
full_df.head(6)

# %%
full_df['channel_title'].value_counts()

# %%
### lets obtain above frequency table using groupby approach :

# %%
cdf = full_df.groupby(['channel_title']).size().sort_values(ascending=False).reset_index()

# %%
cdf = cdf.rename(columns={0:'total_videos'})

# %%
cdf

# %%
import plotly.express as px

# %%
px.bar(data_frame=cdf[0:20] , x='channel_title' , y='total_videos')

# %% [markdown]
# ## 10.. Does Punctuations in title and tags have any relation with views, likes, dislikes comments?

# %%
full_df['title'][0]

# %%
import string

# %%
string.punctuation

# %%
len([char for char in full_df['title'][0] if char in string.punctuation])

# %%
def punc_count(text):
    return len([char for char in text if char in string.punctuation])

# %%
sample = full_df[0:10000]

# %%
sample['count_punc'] = sample['title'].apply(punc_count)

# %%
sample['count_punc']

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = 'count_punc' , y = 'views' , data = sample)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='count_punc' , y='likes' , data=sample)
plt.show()
